# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/3_Project/1_EDA_Intro.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Exploratory Data Analysis & Intro

# %% [markdown]
# ## Goal
#
# 1. Investigate top-paying roles and skills in the data science industry.
# 2. Use Python to explore a real-live dataset on job postings.
# 3. For job-seekers: use these insights to help find the best job opportunities.

# %% [markdown]
# ## Final Deliverables:
# - Create Jupyter Notebookss (showcasing core skills in Python).
# - Create a summary page (via [README.md](README.md)) capturing your findings.
# - Share this project via GitHub & LinkedIn.

# %% [markdown]
# ## Questions to Answer
#
# 1. What are the most demanded skills for the top 3 most popular data roles?
# 2. How are in-demand skills trending for Data Analysts?
# 3. How well do jobs and skills pay for Data Analysts?
# 4. What is the most optimal skill to learn for Data Analysts? (High Demand AND High Paying)
#
# I'll be focusing on US Data Analyst roles

# %% [markdown]
# ## Exploratory Data Analysis for all Data Roles
#
# ### Roles to Explore

# %%
# Importing Libraries
import ast
import pandas as pd
import seaborn as sns
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
#dataset = load_dataset('lukebarousse/data_jobs')
#df = dataset['train'].to_pandas()
df = pd.read_csv("C:/Users/c7gar/OneDrive/Documents/Python/courses/python for data analysis course/Data/job_postings_flat.csv")


# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df_plot = df['job_title_short'].value_counts().to_frame()

sns.set_theme(style='ticks')
sns.barplot(data=df_plot, x='count', y='job_title_short', hue='count', palette='dark:b_r', legend=False)
sns.despine()
plt.title('Number of Jobs per Job Title')
plt.xlabel('Number of Jobs')
plt.ylabel('')
plt.show()

# %% [markdown]
# ### Countries to Explore

# %%
df_plot = df['job_country'].value_counts().to_frame().head(20)

sns.set_theme(style='ticks')
sns.barplot(data=df_plot, x='count', y='job_country', hue='count', palette='dark:b_r', legend=False)
sns.despine()
plt.title('Number of Jobs per Country')
plt.xlabel('Number of Jobs')
plt.ylabel('')
plt.show()

# %% [markdown]
# ### Companies to Explore

# %%
df_plot = df['company_name'].value_counts().to_frame()[1:].head(20)

sns.set_theme(style='ticks')
sns.barplot(data=df_plot, x='count', y='company_name', hue='count', palette='dark:b_r', legend=False)
sns.despine()
plt.title('Number of Jobs per Company')
plt.xlabel('Number of Jobs')
plt.ylabel('')
plt.show()

# %% [markdown]
# ### Job Opportunities

# %%
dict_column = {
    'job_work_from_home': 'Work from Home Offered',
    'job_no_degree_mention': 'Degree Requirement',
    'job_health_insurance': 'Health Insurance Offered'
}

fig, ax = plt.subplots(1, 3, figsize=(11, 3.5))

for i, (column, title) in enumerate(dict_column.items()):
    ax[i].pie(df[column].value_counts(), labels=['False', 'True'], autopct='%1.1f%%', startangle=90)
    ax[i].set_title(title)

plt.show()

# %% [markdown]
# ## Exploratory Data Analysis for Data Analysts in the US

# %%
# Importing Libraries
import ast
import pandas as pd
import seaborn as sns
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
#dataset = load_dataset('lukebarousse/data_jobs')
#df = dataset['train'].to_pandas()
df = pd.read_csv("C:/Users/c7gar/OneDrive/Documents/Python/courses/python for data analysis course/Data/job_postings_flat.csv")

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %% [markdown]
# ### Filter for US Data Analyst roles

# %%
df_DA_US = df[(df['job_country'] == 'United States') & (df['job_title_short'] == 'Data Analyst')]

df_DA_US.head(5)
# Out:
#   job_title_short         job_title    job_location            job_via  \
# 0    Data Analyst      Data Analyst    New York, NY  via CareerBuilder
# 1    Data Analyst      Data Analyst  Washington, DC  via CareerBuilder
# 2    Data Analyst      Data Analyst     Fairfax, VA  via CareerBuilder
# 4    Data Analyst      Data Analyst   Sunnyvale, CA  via CareerBuilder
# 5    Data Analyst  Jr. Data Analyst    Torrance, CA    via Recruit.net
#
#   job_schedule_type  job_work_from_home            search_location  \
# 0         Full-time               False    New York, United States
# 1         Full-time               False    New York, United States
# 2         Full-time               False    New York, United States
# 4         Full-time               False  California, United States
# 5         Full-time               False  California, United States
#
#       job_posted_date  job_no_degree_mention  job_health_insurance  \
# 0 2023-01-01 00:00:04                  False                 False
# 1 2023-01-01 00:00:22                  False                  True
# 2 2023-01-01 00:00:24                  False                 False
# 4 2023-01-01 00:00:38                  False                 False
# 5 2023-01-01 00:00:38                  False                 False
#
#      job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 0  United States         NaN              NaN              NaN
# 1  United States         NaN              NaN              NaN
# 2  United States         NaN              NaN              NaN
# 4  United States         NaN              NaN              NaN
# 5  United States         NaN              NaN              NaN
#
#            company_name                                         job_skills  \
# 0  Metasys Technologies          [sql, snowflake, visio, jira, confluence]
# 1            Guidehouse  [sql, python, r, azure, snowflake, databricks,...
# 2               Protask                                        [sql, jira]
# 4           ICONMA, LLC                                      [sql, python]
# 5                Aquent                                            [excel]
#
#                                      job_type_skills
# 0  {'analyst_tools': ['visio'], 'async': ['jira',...
# 1  {'analyst_tools': ['tableau', 'excel'], 'cloud...
# 2        {'async': ['jira'], 'programming': ['sql']}
# 4                 {'programming': ['sql', 'python']}
# 5                       {'analyst_tools': ['excel']}

# %% [markdown]
# ### Locations to Explore:

# %%
df_plot = df_DA_US['job_location'].value_counts().head(10).to_frame()

sns.set_theme(style='ticks')
sns.barplot(data=df_plot, x='count', y='job_location', palette='dark:b_r', hue='count', legend=False)
sns.despine()
plt.title('Counts of Job Locations for Data Analyst in the US')
plt.xlabel('Number of Jobs')
plt.ylabel('')
plt.show()

# %% [markdown]
# ### Job Opportunities

# %%
# rewrite the above with a for loop
dict_column = {
    'job_work_from_home': 'Work from Home Offered',
    'job_no_degree_mention': 'Degree Requirement',
    'job_health_insurance': 'Health Insurance Offered'
}

fig, ax = plt.subplots(1, 3)
fig.set_size_inches((12, 5))

for i, (column, title) in enumerate(dict_column.items()):
    ax[i].pie(df_DA_US[column].value_counts(), labels=['False', 'True'], autopct='%1.1f%%', startangle=90)
    ax[i].set_title(title)

# plt.suptitle('Benefit Analysis of Data Jobs', fontsize=16)
plt.show()

# %% [markdown]
# ### Companies to Explore:

# %%
df_plot = df_DA_US['company_name'].value_counts().head(10).to_frame()

sns.set_theme(style='ticks')
sns.barplot(data=df_plot, x='count', y='company_name', hue='count', palette='dark:b_r', legend=False)
sns.despine()
plt.title('Counts of Companies for Data Analyst in the US')
plt.xlabel('Number of Jobs')
plt.ylabel('')
plt.show()

# %%
import matplotlib.ticker as ticker

# %%
df_plot = df_DA_US.groupby('job_location')['salary_year_avg'].median().reset_index(name='median_salary')

df_plot = df_plot.sort_values('median_salary', ascending=False).head(10)

sns.set_theme(style='ticks')
sns.barplot(data=df_plot, x='median_salary', y='job_location', palette='dark:b_r') 
sns.despine()
plt.title('Median Salaries by Job Location for Data Analyst in the US')
plt.xlabel('')
plt.ylabel('')

# Format x-axis with $ and commas
plt.gca().xaxis.set_major_formatter(plt.FuncFormatter(lambda x, pos: f'${int(x/1000)}k'))

plt.show()
# Out:
# C:\Users\c7gar\AppData\Local\Temp\ipykernel_3016\386240958.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_plot, x='median_salary', y='job_location', palette='dark:b_r')
